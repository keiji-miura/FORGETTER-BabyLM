# %% [markdown]
# # Baby10M

# %% [markdown]
# # Figure 1

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4.12))
Layers =  [ 9, 12, 16, 18, 22,  24, 30, 36, 48, 54]
N_heads = [16, 10,  8,  6,  8,   5,  4,  4,  3,  3]

x = [x/10 for x in range(90,541)]
y = [120/x*10 for x in range(90,541)]
plt.plot(Layers, N_heads, "-ok", linewidth=3, label="Optimized Models")
plt.plot(x,  y, "--", label='"120-Rule"')
plt.xlabel('Number of Layers', fontsize=20)
plt.ylabel('Number of Heads per Layer', fontsize=20)
plt.tick_params(labelsize=18)
plt.yticks(range(2,17,2))
plt.grid()
plt.title("Baby10M, Normal", fontsize=16)
plt.legend(loc="upper right", fontsize=16, facecolor="white", framealpha=1)

# %% [markdown]
# # Figure 2

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
Layers =   [     9,     12,     16,     18,     22,     24,     30,     36,     48,     54]
Val_loss = [3.0603, 3.0543, 3.0526, 3.0504, 3.0505, 3.0484, 3.0493, 3.0480, 3.0457, 3.0505]
LayersF=   [     9,     12,     16,     18,     22,     24,     30,     36]
Val_lossF= [3.0152, 3.0071, 3.0087, 3.0139, 3.0053, 3.0112, 3.0142, 3.0186]

plt.plot(Layers, Val_loss, "-o", linewidth=3, label="Normal")
plt.plot(LayersF,Val_lossF, "-or", linewidth=3, label="FORGETTER")
plt.xlabel('Number of Layers', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby10M", fontsize=16)
plt.legend(loc="lower right", fontsize=16)

# %% [markdown]
# # Figure 3

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(19600*512*12/1000000000, 3.0603, "o", label="Normal")
x = [i*10000*512*12/1000000000 for i in range(1,20)]
y = [3.1532, 3.0680, 3.0489, 3.0404, 3.0361, 3.0337, 3.0314, 3.0289, 3.0275, 3.0269, 3.0254, 3.0253, 3.0246, 3.0228, 3.0222, 3.0210, 3.0209, 3.0152, 3.0166]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")

plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby10M, L9", fontsize=16)
plt.legend(loc="upper right", fontsize=16) # [+9, 16, 4, 704, 2816, 224, 145.7,+3.0152, 19, 3.0166, 3.0219, 2.7185, 10000, 0.0000]

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(19600*512*12/1000000000, 3.0543, "o", label="Normal")
x = [i*10000*512*12/1000000000 for i in range(1,20)]
y = [3.1561, 3.0575, 3.0406, 3.0340, 3.0302, 3.0292, 3.0254, 3.0236, 3.0229, 3.0210, 3.0198, 3.0192, 3.0183, 3.0177, 3.0177, 3.0174, 3.0165, 3.0071, 3.0082]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")

plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby10M, L12", fontsize=16)
plt.legend(loc="upper right", fontsize=16) # [+12,12, 4, 768, 3072, 192, 180.3,+3.0094,19, 3.0102, 3.0181, 2.6899, 10000, 0.0000],

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(19600*512*12/1000000000, 3.0526, "o", label="Normal")
x = [i*11000*512*12/1000000000 for i in range(1,10)] + [9*11000*512*12/1000000000+9000*512*12/1000000000] + [9*11000*512*12/1000000000+2*9000*512*12/1000000000]
y = [3.1450, 3.0508, 3.0317, 3.0241, 3.0213, 3.0199, 3.0184, 3.0180, 3.0160, 3.0097, 3.0109]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")

plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby10M, L16", fontsize=16)
plt.legend(loc="upper right", fontsize=16)
# [ 16, 8, 4, 704, 2816, 272, 204.2, 3.0160, 9, 3.0174, 3.0180, 2.7260, 11000], #learning_rate=10.5e-4, weight_decay=1.0
# [ 16, 8, 4, 704, 2816, 272, 204.2, 3.0097, 1, 3.0109,  10000, 2.6903,  9000], #learning_rate=9.5e-4, weight_decay=0.9

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(19600*512*12/1000000000, 3.0504, "o", label="Normal")
x = [i*10000*512*12/1000000000 for i in range(1,13)]
y = [3.1813, 3.0600, 3.0401, 3.0328, 3.0278, 3.0261, 3.0243, 3.0224, 3.0220, 3.0202, 3.0148, 3.0167]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")

plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby10M, L18", fontsize=16)
plt.legend(loc="upper right", fontsize=16) # [ 18, 8, 4, 672, 2688, 224, 196.5,+3.0148, 12, 3.0167, 3.0208, 2.7098, 10000, 0.0000],

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(19600*512*12/1000000000, 3.0508, "o", label="Normal")
x = [i*11000*512*12/1000000000 for i in range(1,13)]
y = [3.1247, 3.0536, 3.0379, 3.0310, 3.0261, 3.0233, 3.0211, 3.0182, 3.0162, 3.0122, 3.0108, 3.1759]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")

plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby10M, L20", fontsize=16)
plt.legend(loc="upper right", fontsize=16)
#[+20, 8, 4, 704, 2816, 256, 241.0,+3.0162, 9, 3.0170, 3.0182, 2.7230, 11000], # lr10.5 WD1
#[+20, 8, 4, 704, 2816, 256, 241.0,+3.0108, 2, 3.1759, 3.0122, 2.7514, 11000], # continued lr11e-4 WD1

## L20 Normal Model
#[ 20, 8, 4, 704, 2816, 272, 246.4, 3.4022,+3.0508, 19600], # minGemma-hidden_layers20-att_heads8-kv_heads4-hidden704-intermediate2816-head_dim272-T512--2025-05-03-23-24

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(19600*512*12/1000000000, 3.0508, "o", label="Normal")
x = [i*11000*512*12/1000000000 for i in range(1,9)] + [(8*11000+9000)*512*12/1000000000] + [(8*11000+2*9000)*512*12/1000000000] + [(8*11000+3*9000)*512*12/1000000000]
y = [3.1314, 3.0526, 3.0336, 3.0257, 3.0204, 3.0193, 3.0178, 3.0164, 3.0100, 3.0053, 3.0078]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")

plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby10M, L22", fontsize=16)
plt.legend(loc="upper right", fontsize=16)

#[+22, 8, 4, 672, 2688, 192, 221.3,+3.0164, 8, 3.0948, 3.0178, 2.7259, 11000], # 10.5e-4 WD1 minGemma-hidden_layers22-att_heads8-kv_heads4-hidden672-intermediate2688-head_dim192-T512--2025-05-14-13-11
# Continued 9.5e-4 WD0.9 # minGemma-hidden_layers22-att_heads8-kv_heads4-hidden672-intermediate2688-head_dim192-T512--2025-05-17-06-15

# %% [markdown]
# # Baby100M

# %% [markdown]
# # Figure 4

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
Layers =   [     8,      9,     12,     16,     18,     24,     30,     36]
Val_loss = [2.4862, 2.4840, 2.4740, 2.4714, 2.4691, 2.4748, 2.4812, 2.4858]
LayersF=   [     8,      9,     12,     16,     18,     24,     30] #      6 #     10
Val_lossF= [2.4628, 2.4457, 2.4416, 2.4374, 2.4402, 2.4437, 2.4504] # 2.4688 # 2.4542
plt.plot(Layers, Val_loss, "-o", linewidth=3, label="Normal")
plt.plot(LayersF,Val_lossF, "-or", linewidth=3, label="FORGETTER")
plt.xlabel('Number of Layers', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby100M", fontsize=16)
plt.legend(loc="center right", fontsize=16)

# %% [markdown]
# # Figure 5

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(144000*512*28/1000000000, 2.4840, "o", label="Normal")
x = [i*70000*512*28/1000000000 for i in range(1,24)]
y = [2.5253, 2.4815, 2.4687, 2.4630, 2.4592, 2.4562, 2.4543, 2.4534, 2.4518, 2.4510, 2.4503, 2.4496, 2.4489, 2.4486, 2.4478, 2.4474, 2.4473, 2.4471, 2.4469, 2.4468, 2.4463, 2.4457, 2.4460]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")

plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby100M, L9", fontsize=16)
plt.legend(loc="upper right", fontsize=16)

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(144000*512*28/1000000000, 2.4740, "o", label="Normal")
x = [i*70000*512*28/1000000000 for i in range(1,31)]
y = [2.5152, 2.4759, 2.4658, 2.4607, 2.4575, 2.4559, 2.4544, 2.4526, 2.4509, 2.4497, 2.4488, 2.4479, 2.4474, 2.4464, 2.4455, 2.4450, 2.4446, 2.4443, 2.4443, 2.4437, 2.4436, 2.4432, 2.4432, 2.4425, 2.4424, 2.4423, 2.4420, 2.4418, 2.4416, 2.4417]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")

plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby100M, L12", fontsize=16)
plt.legend(loc="upper right", fontsize=16)

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(144000*512*28/1000000000, 2.4714, "o", label="Normal")
x = [i*70000*512*28/1000000000 for i in range(1,14)]
y = [2.5191, 2.4755, 2.4626, 2.4564, 2.4528, 2.4509, 2.4485, 2.4472, 2.4461, 2.4453, 2.4449, 2.4434, 2.4436]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")

plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby100M, L16", fontsize=16) # part 2
plt.legend(loc="upper right", fontsize=16)

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(144000*512*28/1000000000, 2.4714, "o", label="Normal")
x = [i*70000*512*28/1000000000 for i in range(1,22)]
y = [2.5275, 2.4809, 2.4667, 2.4600, 2.4561, 2.4528, 2.4506, 2.4485, 2.4470, 2.4462, 2.4453, 2.4439, 2.4433, 2.4426, 2.4422, 2.4417, 2.4416, 2.4414, 2.4411, 2.4406, 2.4408]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")

plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby100M, L16", fontsize=16)
plt.legend(loc="upper right", fontsize=16)

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(144000*512*28/1000000000, 2.4691, "o", label="Normal")
x = [i*70000*512*28/1000000000 for i in range(1,21)]
y = [2.5205, 2.4801, 2.4675, 2.4617, 2.4578, 2.4547, 2.4532, 2.4514, 2.4502, 2.4491, 2.4478, 2.4471, 2.4459, 2.4451, 2.4441, 2.4434, 2.4425, 2.4420, 2.4406, 2.4407]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")

plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby100M, L18", fontsize=16)
plt.legend(loc="upper right", fontsize=16)

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(144000*512*28/1000000000, 2.4748, "o", label="Normal") # check the value
x = [i*70000*512*28/1000000000 for i in range(1,15)]
y = [2.5016, 2.4695, 2.4602, 2.4562, 2.4533, 2.4509, 2.4498, 2.4484, 2.4472, 2.4463, 2.4452, 2.4450, 2.4437, 2.4439]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")
plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("Baby100M, L24", fontsize=16)
plt.legend(loc="upper right", fontsize=16)

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
plt.plot(144000*512*28/1000000000, 2.4812, "o", label="Normal") # check the value
x = [i*70000*512*28/1000000000 for i in range(1,18)]
y = [2.5089, 2.4737, 2.4632, 2.4596, 2.4576, 2.4565, 2.4557, 2.4555, 2.4541, 2.4538, 2.4531, 2.4529, 2.4520, 2.4519, 2.4513, 2.4504, 2.4505]
plt.plot(x,y,'-or', linewidth=3, label="FORGETTER")
plt.xlabel('Training Data Size (Billion Tokens)', fontsize=20)
plt.ylabel('Validated Loss', fontsize=20)
plt.tick_params(labelsize=18); plt.locator_params(axis='x', integer=True)
plt.title("Baby100M, L30", fontsize=16)
plt.legend(loc="upper right", fontsize=16)

# %% [markdown]
# # CIFAR10

# %%
import matplotlib.pyplot as plt; plt.figure(figsize=(8,4))
x = [i*7 for i in range(1,13)]
y = [0.8403, 0.8549, 0.8562, 0.8635, 0.8648, 0.8628, 0.8633, 0.8612, 0.8666, 0.8656, 0.8659, 0.8624]
y2= [0.8530, 0.8632, 0.8660, 0.8711, 0.8740, 0.8726, 0.8760, 0.8777, 0.8733, 0.8734, 0.8752, 0.8796]
plt.plot(10, 0.8609, "o", label="Normal w/ dropout (p=1/6)")
plt.plot(x,y2,'-o', color="red", linewidth=3, label="FORGETTER w/ dropout (p=1/6)")
plt.plot(10, 0.8515, "o", color="lightblue", label="Normal w/o dropout (p=0)")
plt.plot(x,y, '-o', color="orange", linewidth=3, label="FORGETTER w/o dropout (p=0)")
plt.xlabel('Training Data Size (number of epochs)', fontsize=20)
plt.ylabel('Accuracy', fontsize=20)
plt.tick_params(labelsize=18)
plt.title("CIFAR10", fontsize=16)
plt.legend(loc="lower right", fontsize=16)
